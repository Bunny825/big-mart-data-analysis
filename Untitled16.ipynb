# %% [markdown]
# <a href="https://colab.research.google.com/github/Bunny825/big-mart-data-analysis/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

# %%
big_mart_data=pd.read_csv("/content/big_mart_data.csv")
big_mart_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
big_mart_data.shape
# Out:
# (8523, 12)

# %%
big_mart_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#filling the missing values

big_mart_data["Item_Weight"].fillna(big_mart_data["Item_Weight"].mean(),inplace=True)
big_mart_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
category_wise_mode=big_mart_data.pivot_table(values="Outlet_Size",columns="Outlet_Type",aggfunc=(lambda x:x.mode()[0]))
print(category_wise_mode)
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
missing_values=big_mart_data["Outlet_Size"].isnull()
print(missing_values)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8518    False
# 8519     True
# 8520    False
# 8521    False
# 8522    False
# Name: Outlet_Size, Length: 8523, dtype: bool

# %%
big_mart_data.loc[missing_values, "Outlet_Size"] = big_mart_data.loc[missing_values, "Outlet_Type"].apply(
    lambda x: category_wise_mode[x] if x in category_wise_mode else np.nan
)

# %%
big_mart_data.isnull().sum()
big_mart_data["Outlet_Size"].value_counts()
# Out:
# Outlet_Size
# Small     4798
# Medium    2793
# High       932
# Name: count, dtype: int64

# %% [markdown]
# #**Data Analysis**

# %%
big_mart_data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
sns.set()
#data distribution for Item_Weight
plt.figure(figsize=(6,6))
sns.displot(big_mart_data["Item_Weight"],kde=True)
plt.show()

# %%
#data distribution for Item_Visibility
plt.figure(figsize=(6,6))
sns.displot(big_mart_data["Item_Visibility"],kde=True)
plt.show()

# %%
#data distribution for Item_MRP
plt.figure(figsize=(6,6))
sns.displot(big_mart_data["Item_MRP"],kde=True)
plt.show()

# %%
#counts for Outlet_Establishment_Year
plt.figure(figsize=(10,6))
sns.countplot(x="Outlet_Establishment_Year",data=big_mart_data)
plt.show()

# %%
#graphs for the catergorical data columns

big_mart_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
plt.figure(figsize=(6,6))
sns.countplot(x="Item_Fat_Content",data=big_mart_data)
plt.show()

# %%
#here all the Low Fat,low fat,LF all are same and we should change or merge them into a single category which is similar with the Regular and reg
plt.figure(figsize=(30,6))
sns.countplot(x="Item_Type",data=big_mart_data)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x="Outlet_Location_Type",data=big_mart_data)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Outlet_Type",data=big_mart_data)
plt.show()

# %%
#handling the Item_Fat_Content column which needs the merging of catogories.Let's handle it now

big_mart_data.replace({"Item_Fat_Content":{"low fat":"Low Fat","LF":"Low Fat","reg":"Regular"}},inplace=True)

# %%
big_mart_data["Item_Fat_Content"].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %% [markdown]
# #**Data-PreProcessing**

# %%
#changing the categorical values to numerical values

encoder=LabelEncoder()
big_mart_data["Item_Identifier"]=encoder.fit_transform(big_mart_data["Item_Identifier"])
big_mart_data["Item_Type"]=encoder.fit_transform(big_mart_data["Item_Type"])
big_mart_data["Outlet_Identifier"]=encoder.fit_transform(big_mart_data["Outlet_Identifier"])
big_mart_data["Outlet_Size"]=encoder.fit_transform(big_mart_data["Outlet_Size"])
big_mart_data["Outlet_Location_Type"]=encoder.fit_transform(big_mart_data["Outlet_Location_Type"])
big_mart_data["Outlet_Type"]=encoder.fit_transform(big_mart_data["Outlet_Type"])
big_mart_data["Item_Fat_Content"]=encoder.fit_transform(big_mart_data["Item_Fat_Content"])

# %%
big_mart_data.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            2
# 4   53.8614                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %% [markdown]
# #**Splitting the features and the target**

# %%
x=big_mart_data.drop(columns="Item_Outlet_Sales",axis=1)
y=big_mart_data["Item_Outlet_Sales"]
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=5,test_size=0.2)
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (8523, 11) (6818, 11) (1705, 11)

# %% [markdown]
# #**Model Training**

# %%
from sklearn.model_selection import RandomizedSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9],
    'reg_alpha': [0, 0.1, 1, 10],
    'reg_lambda': [1, 10, 100]
}

grid_search = RandomizedSearchCV(XGBRegressor(), param_grid, cv=5, scoring='r2', verbose=1)
grid_search.fit(x_train, y_train)
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'subsample': 0.8, 'reg_lambda': 10, 'reg_alpha': 0, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.05, 'colsample_bytree': 0.9}
# 0.5988948754676178

# %%
model=XGBRegressor(n_estimators=300,
    learning_rate=0.05,
    max_depth=3,
    reg_alpha=10,reg_lambda=100,subsample=0.8,min_child_weight=3,colsample_bytree=0.7)
model.fit(x_train,y_train)

train_pred=model.predict(x_train)
train_r2=metrics.r2_score(y_train,train_pred)

test_pred=model.predict(x_test)
test_r2=metrics.r2_score(y_test,test_pred)

print("r2 score of train data:",train_r2)
print("r2 score of test data:",test_r2)
# Out:
# r2 score of train data: 0.629386939595869
# r2 score of test data: 0.5853287133798444
